# %%
#Load modules

import networkx as nx
# import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

from numpy.random import choice

# %%
def select_nodes_by_kw(graph, keyword_list = []):
    """
    This function returns a list of all nodes whose name contains some of the keywords.
    
    graph: networkx graph object
    
    """
    result_list = []
    for kw in keyword_list:
        result_list += [label for label in graph.nodes() if kw in label]
    return result_list

def second_neighbors(graph, nodes, second_order = True):
    """
    graph: networkx graph
    nodes: list of node names
    second_order: If 'False' search stops at direct (1st order) neighborhood. 
    Returns subgraph with up to second neighbors of node, and edges between them.                                                                              
    """
    neighbor_list = [nodes]

    for i in range(len(nodes)):
        neighbor_list += [graph.neighbors(nodes[i])]
        
        if second_order == True:
            for n in graph.neighbors(nodes[i]):
                    neighbor_list += [graph.neighbors(n)]


    return list(set([item for sublist in neighbor_list for item in sublist]))

def wrap_by_word(s, n):
    '''returns a string where \\n is inserted between every n words'''
    a = s.split()
    ret = ''
    for i in range(0, len(a), n):
        ret += ' '.join(a[i:i+n]) + ' \n '

    return ret

# %%
# Columns of the datasets
# Geo_cat = ['CHI ID COM']#'BRA ID MIR'
# HS_cat = ['HS ID 6']
# ind_cat = ['CIIU ID 4']

Geo_cat = ['BRA ID MIR'] #'BRA ID MIR'
HS_cat = ['HS ID 4']
ind_cat = ['CNAE ID C', 'CBO ID F']


var = 'Total Yearly Wages' # 'output_USD'
var_str = '_w'
var_lab_str = 'Wages in '# 'Output of ' #'Wages in '

# %%
#Choose a configuration for further aggregation.

# ctry_str = Geo_cat[0][:3]
# geo_str = Geo_cat[0][-3:]

# confs = [('4', '2', '2'),
#          ('4', '4', '2')]

# confs = [('0', 'G', '4', '4'),
#          ('GG', 'D', '4', '4'),
#          ('SGP', 'S', '4', '4'),
#          ('SGP', 'S', '4', '4')]

# for conf in confs:
# #     (CIIU_lev, HS_Exp, HS_Imp) = conf
#     (CBO_lev, CNAE_lev, HS_Exp, HS_Imp) = conf

#     col_name = ctry_str+'_'+geo_str+'_'+'_'.join([c for c in conf])+var_str
#     print col_name

# %%
# Path where structure reference tables are:
path = 'data/disagg_struct_refs/formatted/'

GEO_chi = pd.read_csv('data/disagg_struct_refs/formatted/GEO_chi.csv')
GEO_bra = pd.read_csv('data/disagg_struct_refs/formatted/GEO_bra.csv')

GEO_bra['BRA label EST'] = GEO_bra['BRA ID EST']
GEO_bra['BRA label MER'] = GEO_bra['BRA ID MER']
GEO_bra['BRA label MIR'] = GEO_bra['BRA ID MIR']

# %%
import itertools
from collections import OrderedDict
from numpy import array

geo_levs = ['CHI_REG', 'CHI_PRO', 'CHI_COM']
geo_levs = ['CHI_COM']
J = len(geo_levs)

# This dictionary summarises the possible configurations for the experiment.
# 'name' points to the variable names, eg. ['Wages', 'Exports', 'Imports']
# 'dataset' tells us the name of the dataset that each of the variables above belong to.
# 'levels' tells the disaggregation levels we would like each variable to be analised in.
# 'agg_str' is the name of the dataset used for reference of the disaggregation, for each of the variables
var_dict = {'name': ['Wages', 'Exports', 'Imports'], 
       'dataset': ['prd', 'trd', 'trd'], 
       'levels': [['CI1', 'CI2','CI4'], ['HS1', 'HS2','HS4'], ['HS1', 'HS2']],
           'agg_str' : ['CIIU', 'HS', 'HS']}

var_dict = {'name': ['Wages', 'Output', 'Exports', 'Imports'], 
       'dataset': ['prd','prd', 'trd', 'trd'], 
       'levels': [['CI1', 'CI2', 'CI4'],['CI1', 'CI2', 'CI4'], ['HS1', 'HS2', 'HS4'], ['HS1', 'HS2', 'HS4']],
#            'agg_ref' : [CIIU, CIIU, HS, HS],
           'agg_str' : ['CIIU','CIIU', 'HS', 'HS']}

# The brazil case may be more special cause aggregation of the production dataset is over two directions
# var_dict = {'name': ['Wages', 'Output', 'Exports', 'Imports'], 
#        'dataset': ['prd','prd', 'trd', 'trd'], 
#        'levels': [['CN1', 'CN2', 'CN4'],['CN1', 'CN2', 'CN4'], ['HS1', 'HS2', 'HS4'], ['HS1', 'HS2', 'HS4']],
# #            'agg_ref' : [CIIU, CIIU, HS, HS],
#            'agg_str' : ['CNAE','CNAE', 'HS', 'HS']}


# all possible combination of levels. They could be filtered afterwards...
confs = list(itertools.product(*var_dict['levels']))

#select(sample) every three
confs = array(confs)[[i for i in range(len(confs)) if i%6 == 0]]
K = len(confs)

# %%
import seaborn as sns
import math

from bokeh.io import show, output_file, save
from bokeh.plotting import figure
from bokeh.models import GraphRenderer, StaticLayoutProvider, Circle, MultiLine, NodesOnly, NodesAndLinkedEdges, EdgesAndLinkedNodes
from bokeh.models.graphs import from_networkx
from bokeh.models.tools import HoverTool

from numpy import power

# Maximum degree that a network can have.
max_d = 10

# String that identifies the right 'weight' column in the edges dataset. 
# also used as prefix in the configuration name
geo = 'CHI_COM'


# Column of name and id of geographical units.
places_id = 'CHI ID COM'#'BRA ID MIR' #'CHI ID COM'
places_label = 'CHI label COM'#'BRA label MIR' #'CHI label COM'
GEO_ref = GEO_chi #GEO_bra #GEO_chi

ctry_str = 'CHI'

path = 'data/new/'
path = './../../../../../media/miglesia/Elements/corr_st_data/'


l = len(geo_levs)

k = .1

for j in range(len(confs)):

#     try:
        
    conf = confs[j]


#     (CIIU_lev, HS_Exp, HS_Imp) = conf
#     (CBO_lev, CNAE_lev, HS_Exp, HS_Imp) = conf
    print conf

#     col_name = ctry_str+'_'+geo_str+'_'+'_'.join([c for c in conf])+var_str
    conf_name = geo+'_'+'_'.join([var_dict['name'][i][0]+conf[i][-1] for i in range(len(var_dict['name']))])


    nodes = pd.read_csv(path+conf_name+'_nodes.csv', index_col = 0)
    edges = pd.read_csv(path+conf_name+'_edges.csv', index_col = 0)

        ### Max degree = max_d. Parameter used to trim the network.
    df1 = edges.groupby('label_x').apply(lambda x: x.nlargest(max_d, 'weight_'+geo)).reset_index(drop = True)
    df2 = edges.groupby('label_y').apply(lambda x: x.nlargest(max_d, 'weight_'+geo)).reset_index(drop = True)
    edges = df1.merge(df2, on = ['label_x', 'label_y', 'weight_'+geo]).reset_index(drop = True)

#     Add info of districts with most volume (CHI)
    ###
    concat_data = pd.read_csv(path+conf_name+'_cc_data.csv', index_col = 0).reset_index()
    df = concat_data.sort_values(by = ['node_name', 'value_USD'])
    
#     node_grouped = df.groupby('node_name')['value_USD']
    node_totals = df.groupby('node_name')['value_USD'].sum().reset_index().rename({'value_USD': 'node_value_USD'}, axis = 1)
    
    df = df.merge(node_totals)

    df['rk'] = df.groupby('node_name')['value_USD'].rank(method = 'first', ascending = False)
    df['pct'] = df['value_USD'].div(df['node_value_USD']).multiply(100).dropna().round(1)

    df = df.loc[df.rk <= 3].merge(GEO_ref[[places_id, places_label]].drop_duplicates())
    df['info_'] = df[places_label] + ' ('+df.pct.astype(str)+'%)'
    df = df.sort_values(by = 'node_name')
    df = pd.DataFrame(df.set_index(['node_name', 'rk'])[['info_']].unstack())
    # df
    df.columns = df.columns.droplevel(0)

    df['info'] = df[1.0] +', '+ df[2.0]+', '+df[3.0]
    df = df.reset_index()[['node_name', 'info']]

#     nodes = nodes.merge(df[['node_name', 'info']])
    nodes = nodes.merge(df.set_index('node_name')[['info']], left_index = True, right_index = True)

#     ###

    #color
    from matplotlib import colors
    nodes['color_code'] = nodes.att_A.rank(method = 'dense')
    w = plt.cm.get_cmap('rainbow', len(nodes.color_code.unique()))
    
    colors_hex = []
    for i in range(w.N):
        rgb = w(i)[:3] # will return rgba, we take only first 3 so we get rgb
        colors_hex += [colors.rgb2hex(rgb)]

    colors_hex = [w.encode('UTF8') for w in colors_hex]
    code_hex = pd.DataFrame([nodes.color_code.unique(), colors_hex], index = ['color_code', 'color']).T

    #size

    value = nodes['node_value_USD']
    # nodes['node_size'] = np.sqrt((value/value.median()).values)
    nodes['node_size'] = 10 * power((value/value.median()).values, 1/2.)

#     nodes = nodes.merge(code_hex)
    nodes = nodes.reset_index().merge(code_hex, on = 'color_code').set_index('node_name')
    
    ###

    G = nx.from_pandas_dataframe(edges, 'label_x', 'label_y', 'weight_'+geo)



    ### Subgraph - neighborhood
    # Random choice of some nodes...
    nodes_choice = choice(G.nodes(), 5)

    for node in nodes_choice:

        ix = nodes.loc[node].index.values[0]

        G_s = G.subgraph(second_neighbors(G, [node], second_order=True))  
        nodes_s = nodes.loc[G_s.nodes()].reset_index()
        edges_s = edges.loc[(edges.label_x.isin(G_s.nodes())) & (edges.label_y.isin(G_s.nodes()))]


        # nx.write_gexf(G,'networks/'+col_name+'.gexf')

    #         print 'nodes: '+str(len(G.nodes()))
    #         print 'edges: '+str(len(G.edges()))

        # Subset of nodes
#         nodes_s = nodes.set_index('node_name').loc[G_s.nodes()].reset_index()

        #Perform Graph Drawing
    #     pos = nx.spring_layout(G, k=k)
    #     nx.draw(G, pos, ax = ax, node_size = 5*nodes.node_size.values, alpha=.6, node_color= list(nodes.color.values), edgelist = [])

        #     Bokeh drawing
        ####

        N = len(nodes_s)
        node_indices = list(range(N))
        nodes_s['node_name_'] = [wrap_by_word(s, 5) for s in nodes_s['node_name'].values]

        plot = figure(title=col_name, x_range=(-1.1,1.1), y_range=(-1.1,1.1))

        #####

        graph = from_networkx(G_s, nx.spring_layout, center=(0,0), k = k)

        graph.node_renderer.data_source.add(list(nodes_s['color'].values), 'color')
        graph.node_renderer.data_source.add(list(nodes_s['node_name_'].values), 'node_name_')
        graph.node_renderer.data_source.add(list(nodes_s['node_value_USD'].values), 'node_value_USD')
        graph.node_renderer.data_source.add(list(nodes_s['info'].values), 'info')
        graph.node_renderer.data_source.add(list(.5*nodes_s['node_size'].values), 'node_size')

        graph.node_renderer.glyph = Circle(size='node_size', fill_color='color')
        graph.node_renderer.selection_glyph = Circle(size=15, fill_color='#808000')
        graph.node_renderer.hover_glyph = Circle(size=15, fill_color='#808000')

        graph.edge_renderer.glyph = MultiLine(line_color="#CCCCCC", line_alpha=0.5, line_width=1)
        graph.edge_renderer.selection_glyph = MultiLine(line_color='#808000', line_width=5)
        graph.edge_renderer.hover_glyph = MultiLine(line_color='#808000', line_width=5)
        graph.selection_policy = NodesAndLinkedEdges()
        graph.selection_policy = EdgesAndLinkedNodes()

        plot.renderers.append(graph)

        hover = HoverTool(tooltips=dict(main_place="@info", value="@node_value_USD", activity="@node_name_"))
        # hover = HoverTool(tooltips = [('Info', '@node_name'),('(x,y)', '($x, $y)')])

        plot.add_tools(hover)

        output_file('./Figures/6_neighbhoods/'+col_name+'_'+str(ix).zfill(3)+'.html')
        save(plot)
#     except IOError:
#         print 'IOError at '+str('data/node_refs/'+conf_name+'_nodes.csv')
# Out:
# ['CI1' 'CI1' 'HS1' 'HS1']
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products'',
#        u'Exports of 'Animal Or Vegetable Fats And Oils And Their Cleavage Products; Prepared Edible Fats; Animal Or Vegetable Waxes''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Imports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products''],
#       dtype='object', name=u'node_name')
# ['CI1' 'CI1' 'HS4' 'HS1']
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# ['CI1' 'CI2' 'HS2' 'HS1']
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# ['CI1' 'CI4' 'HS1' 'HS1']
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products'',
#        u'Exports of 'Animal Or Vegetable Fats And Oils And Their Cleavage Products; Prepared Edible Fats; Animal Or Vegetable Waxes''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Imports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products''],
#       dtype='object', name=u'node_name')
# ['CI1' 'CI4' 'HS4' 'HS1']
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# ['CI2' 'CI1' 'HS2' 'HS1']
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# ['CI2' 'CI2' 'HS1' 'HS1']
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products'',
#        u'Exports of 'Animal Or Vegetable Fats And Oils And Their Cleavage Products; Prepared Edible Fats; Animal Or Vegetable Waxes''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Imports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products''],
#       dtype='object', name=u'node_name')
# ['CI2' 'CI2' 'HS4' 'HS1']
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# ['CI2' 'CI4' 'HS2' 'HS1']
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# ['CI4' 'CI1' 'HS1' 'HS1']
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products'',
#        u'Exports of 'Animal Or Vegetable Fats And Oils And Their Cleavage Products; Prepared Edible Fats; Animal Or Vegetable Waxes''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Imports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products''],
#       dtype='object', name=u'node_name')
# ['CI4' 'CI1' 'HS4' 'HS1']
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# ['CI4' 'CI2' 'HS2' 'HS1']
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '01 - Animals; live'',
#        u'Exports of '02 - Meat and edible meat offal'',
#        u'Exports of '03 - Fish and crustaceans, molluscs and other aquatic invertebrates''],
#       dtype='object', name=u'node_name')
# ['CI4' 'CI4' 'HS1' 'HS1']
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products'',
#        u'Exports of 'Animal Or Vegetable Fats And Oils And Their Cleavage Products; Prepared Edible Fats; Animal Or Vegetable Waxes''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of 'Live Animals; Animal Products'',
#        u'Imports of 'Live Animals; Animal Products'',
#        u'Exports of 'Vegetable Products''],
#       dtype='object', name=u'node_name')
# ['CI4' 'CI4' 'HS4' 'HS1']
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')
# Index([u'Exports of '0101 - Horses, asses, mules and hinnies; live'',
#        u'Exports of '0102 - Bovine animals; live'',
#        u'Exports of '0103 - Swine; live''],
#       dtype='object', name=u'node_name')

# %%
# code_hex['color_code'] = code_hex['color_code'].astype(float)


# code_hex.dtypes

# %%
edges#.groupby('label_x').apply(lambda x: x.nlargest(max_d, 'weight_'+geo_str)).reset_index(drop = True)
# Out:
#      index_x                                            label_x  \
# 0          3  Exports of 'Base Metals And Articles Of Base M...
# 1          6  Exports of 'Base Metals And Articles Of Base M...
# 2          4  Exports of 'Base Metals And Articles Of Base M...
# 3          1  Exports of 'Base Metals And Articles Of Base M...
# 4         31  Exports of 'Base Metals And Articles Of Base M...
# 5         18  Exports of 'Base Metals And Articles Of Base M...
# 6         48  Exports of 'Base Metals And Articles Of Base M...
# 7         34  Exports of 'Base Metals And Articles Of Base M...
# 8         62         Exports of 'Live Animals; Animal Products'
# 9         75         Exports of 'Live Animals; Animal Products'
# 10        56         Exports of 'Live Animals; Animal Products'
# 11        92         Exports of 'Live Animals; Animal Products'
# 12        57         Exports of 'Live Animals; Animal Products'
# 13        58         Exports of 'Live Animals; Animal Products'
# 14        53         Exports of 'Live Animals; Animal Products'
# 15       108  Exports of 'Machinery And Mechanical Appliance...
# 16       119  Exports of 'Machinery And Mechanical Appliance...
# 17       112  Exports of 'Machinery And Mechanical Appliance...
# 18       118  Exports of 'Machinery And Mechanical Appliance...
# 19       138  Exports of 'Machinery And Mechanical Appliance...
# 20       116  Exports of 'Machinery And Mechanical Appliance...
# 21       127  Exports of 'Machinery And Mechanical Appliance...
# 22       117  Exports of 'Machinery And Mechanical Appliance...
# 23       125  Exports of 'Machinery And Mechanical Appliance...
# 24       163                      Exports of 'Mineral Products'
# 25       190                      Exports of 'Mineral Products'
# 26       207                      Exports of 'Mineral Products'
# 27       168                      Exports of 'Mineral Products'
# 28       159                      Exports of 'Mineral Products'
# 29       160                      Exports of 'Mineral Products'
# ..       ...                                                ...
# 358     2632                          Wages of 'CIIU seccion 3'
# 359     2700                          Wages of 'CIIU seccion 6'
# 360     2685                          Wages of 'CIIU seccion 6'
# 361     2699                          Wages of 'CIIU seccion 6'
# 362     2688                          Wages of 'CIIU seccion 6'
# 363     2701                          Wages of 'CIIU seccion 6'
# 364     2686                          Wages of 'CIIU seccion 6'
# 365     2682                          Wages of 'CIIU seccion 6'
# 366     2687                          Wages of 'CIIU seccion 6'
# 367     2677                          Wages of 'CIIU seccion 6'
# 368     2754                          Wages of 'CIIU seccion 7'
# 369     2739                          Wages of 'CIIU seccion 7'
# 370     2735                          Wages of 'CIIU seccion 7'
# 371     2752                          Wages of 'CIIU seccion 7'
# 372     2740                          Wages of 'CIIU seccion 7'
# 373     2741                          Wages of 'CIIU seccion 7'
# 374     2755                          Wages of 'CIIU seccion 7'
# 375     2738                          Wages of 'CIIU seccion 7'
# 376     2733                          Wages of 'CIIU seccion 7'
# 377     2753                          Wages of 'CIIU seccion 7'
# 378     2808                          Wages of 'CIIU seccion 8'
# 379     2793                          Wages of 'CIIU seccion 8'
# 380     2805                          Wages of 'CIIU seccion 8'
# 381     2807                          Wages of 'CIIU seccion 8'
# 382     2778                          Wages of 'CIIU seccion 8'
# 383     2795                          Wages of 'CIIU seccion 8'
# 384     2800                          Wages of 'CIIU seccion 8'
# 385     2792                          Wages of 'CIIU seccion 8'
# 386     2788                          Wages of 'CIIU seccion 8'
# 387     2786                          Wages of 'CIIU seccion 8'
#
#                                                label_y  weight_CHI_COM  \
# 0                        Exports of 'Mineral Products'        1.874387
# 1    Exports of 'Products Of The Chemical Or Allied...        1.718824
# 2    Exports of 'Natural Or Cultured Pearls, Precio...        1.242880
# 3           Exports of 'Live Animals; Animal Products'        0.893584
# 4                           Output of 'CIIU seccion 2'        0.886588
# 5    Imports of 'Products Of The Chemical Or Allied...        0.818204
# 6                            Wages of 'CIIU seccion 2'        0.792296
# 7                           Output of 'CIIU seccion 5'        0.588680
# 8    Exports of 'Wood And Articles Of Wood; Wood Ch...        1.834539
# 9                           Output of 'CIIU seccion 1'        1.632827
# 10                       Exports of 'Mineral Products'        1.397166
# 11                           Wages of 'CIIU seccion 1'        1.326607
# 12   Exports of 'Natural Or Cultured Pearls, Precio...        1.230974
# 13   Exports of 'Prepared Foodstuffs; Beverages, Sp...        0.833563
# 14   Exports of 'Base Metals And Articles Of Base M...        0.669392
# 15   Exports of 'Machinery And Mechanical Appliance...        3.758734
# 16                       Imports of 'Mineral Products'        1.379870
# 17   Exports of 'Products Of The Chemical Or Allied...        0.983242
# 18   Imports of 'Machinery And Mechanical Appliance...        0.967325
# 19                          Output of 'CIIU seccion 3'        0.913250
# 20   Imports of 'Base Metals And Articles Of Base M...        0.902031
# 21   Imports of 'Vehicles, Aircraft, Vessels And As...        0.880702
# 22          Imports of 'Live Animals; Animal Products'        0.741350
# 23          Imports of 'Textiles And Textile Articles'        0.700036
# 24   Exports of 'Natural Or Cultured Pearls, Precio...        2.563053
# 25                          Output of 'CIIU seccion 2'        1.956356
# 26                           Wages of 'CIIU seccion 2'        1.478370
# 27   Exports of 'Wood And Articles Of Wood; Wood Ch...        1.338273
# 28   Exports of 'Base Metals And Articles Of Base M...        1.003619
# 29          Exports of 'Live Animals; Animal Products'        0.998648
# ..                                                 ...             ...
# 358                         Output of 'CIIU seccion 6'        0.731227
# 359                          Wages of 'CIIU seccion 6'        3.232631
# 360                         Output of 'CIIU seccion 6'        2.726987
# 361                          Wages of 'CIIU seccion 3'        1.069420
# 362                         Output of 'CIIU seccion 9'        1.041731
# 363                          Wages of 'CIIU seccion 7'        0.913620
# 364                         Output of 'CIIU seccion 7'        0.869040
# 365                         Output of 'CIIU seccion 3'        0.868610
# 366                         Output of 'CIIU seccion 8'        0.803499
# 367                        Output of 'CIIU seccion 14'        0.732312
# 368                          Wages of 'CIIU seccion 7'        2.087455
# 369                         Output of 'CIIU seccion 7'        1.820181
# 370                         Output of 'CIIU seccion 3'        1.030024
# 371                          Wages of 'CIIU seccion 3'        1.026292
# 372                         Output of 'CIIU seccion 8'        1.015044
# 373                         Output of 'CIIU seccion 9'        0.991103
# 374                          Wages of 'CIIU seccion 8'        0.990037
# 375                         Output of 'CIIU seccion 6'        0.949435
# 376                        Output of 'CIIU seccion 19'        0.924200
# 377                          Wages of 'CIIU seccion 6'        0.828966
# 378                          Wages of 'CIIU seccion 8'        3.251913
# 379                         Output of 'CIIU seccion 8'        2.377877
# 380                          Wages of 'CIIU seccion 3'        1.160264
# 381                          Wages of 'CIIU seccion 7'        1.004701
# 382                         Output of 'CIIU seccion 1'        0.984788
# 383                          Wages of 'CIIU seccion 1'        0.980648
# 384                         Wages of 'CIIU seccion 14'        0.947547
# 385                         Output of 'CIIU seccion 7'        0.905663
# 386                         Output of 'CIIU seccion 3'        0.873630
# 387                        Output of 'CIIU seccion 19'        0.863166
#
#      index_y
# 0          3
# 1          6
# 2          4
# 3          1
# 4         31
# 5         18
# 6         48
# 7         34
# 8         62
# 9         75
# 10        56
# 11        92
# 12        57
# 13        58
# 14        53
# 15       108
# 16       119
# 17       112
# 18       118
# 19       138
# 20       116
# 21       127
# 22       117
# 23       125
# 24       163
# 25       190
# 26       207
# 27       168
# 28       159
# 29       160
# ..       ...
# 358     2632
# 359     2700
# 360     2685
# 361     2699
# 362     2688
# 363     2701
# 364     2686
# 365     2682
# 366     2687
# 367     2677
# 368     2754
# 369     2739
# 370     2735
# 371     2752
# 372     2740
# 373     2741
# 374     2755
# 375     2738
# 376     2733
# 377     2753
# 378     2808
# 379     2793
# 380     2805
# 381     2807
# 382     2778
# 383     2795
# 384     2800
# 385     2792
# 386     2788
# 387     2786
#
# [388 rows x 5 columns]

# %%
pd.read_csv('data/new/'+conf_name+'_log_corr.csv', index_col = 0)
# Out:
#                                                     Exports of 'Animal Or Vegetable Fats And Oils And Their Cleavage Products; Prepared Edible Fats; Animal Or Vegetable Waxes'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                                           1.000000
# Exports of 'Arms And Ammunition; Parts And Acce...                                           0.104838
# Exports of 'Articles Of Stone, Plaster, Cement,...                                           0.360671
# Exports of 'Base Metals And Articles Of Base Me...                                           0.550118
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.454870
# Exports of 'Live Animals; Animal Products'                                                   0.398582
# Exports of 'Machinery And Mechanical Appliances...                                           0.449944
# Exports of 'Mineral Products'                                                                0.250478
# Exports of 'Miscellaneous Manufactured Articles'                                             0.358156
# Exports of 'Natural Or Cultured Pearls, Preciou...                                           0.281717
# Exports of 'Optical, Photographic, Cinematograp...                                           0.494059
# Exports of 'Plastics And Articles Thereof; Rubb...                                           0.507331
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.264623
# Exports of 'Products Of The Chemical Or Allied ...                                           0.442148
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.339791
# Exports of 'Raw Hides And Skins, Leather, Fursk...                                           0.280825
# Exports of 'Textiles And Textile Articles'                                                   0.480255
# Exports of 'Vegetable Products'                                                              0.044474
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.449262
# Exports of 'Wood And Articles Of Wood; Wood Cha...                                           0.243931
# Exports of 'Works Of Art, Collectors' Pieces An...                                           0.664073
# Imports of 'Animal Or Vegetable Fats And Oils A...                                           0.199973
# Imports of 'Arms And Ammunition; Parts And Acce...                                           0.388034
# Imports of 'Articles Of Stone, Plaster, Cement,...                                           0.353508
# Imports of 'Base Metals And Articles Of Base Me...                                           0.434343
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.407895
# Imports of 'Live Animals; Animal Products'                                                   0.408554
# Imports of 'Machinery And Mechanical Appliances...                                           0.444238
# Imports of 'Mineral Products'                                                                0.418999
# Imports of 'Miscellaneous Manufactured Articles'                                             0.350887
# ...                                                                                               ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.456954
# Imports of 'Products Of The Chemical Or Allied ...                                           0.394344
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.401465
# Imports of 'Raw Hides And Skins, Leather, Fursk...                                           0.342449
# Imports of 'Textiles And Textile Articles'                                                   0.351982
# Imports of 'Vegetable Products'                                                              0.343669
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.351063
# Imports of 'Wood And Articles Of Wood; Wood Cha...                                           0.308874
# Imports of 'Works Of Art, Collectors' Pieces An...                                           0.411005
# Wages of 'CIIU seccion 1'                                                                    0.252140
# Wages of 'CIIU seccion 10'                                                                   0.387345
# Wages of 'CIIU seccion 11'                                                                   0.404256
# Wages of 'CIIU seccion 12'                                                                   0.333035
# Wages of 'CIIU seccion 13'                                                                   0.362549
# Wages of 'CIIU seccion 14'                                                                   0.347207
# Wages of 'CIIU seccion 15'                                                                   0.166620
# Wages of 'CIIU seccion 16'                                                                   0.254105
# Wages of 'CIIU seccion 17'                                                                   0.331577
# Wages of 'CIIU seccion 18'                                                                   0.180363
# Wages of 'CIIU seccion 19'                                                                   0.315164
# Wages of 'CIIU seccion 2'                                                                    0.361415
# Wages of 'CIIU seccion 20'                                                                   0.377973
# Wages of 'CIIU seccion 21'                                                                   0.356264
# Wages of 'CIIU seccion 3'                                                                    0.389450
# Wages of 'CIIU seccion 4'                                                                    0.308749
# Wages of 'CIIU seccion 5'                                                                    0.316131
# Wages of 'CIIU seccion 6'                                                                    0.474191
# Wages of 'CIIU seccion 7'                                                                    0.393349
# Wages of 'CIIU seccion 8'                                                                    0.376562
# Wages of 'CIIU seccion 9'                                                                    0.321524
#
#                                                     Exports of 'Arms And Ammunition; Parts And Accessories Thereof'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                                           0.104838
# Exports of 'Arms And Ammunition; Parts And Acce...                                           1.000000
# Exports of 'Articles Of Stone, Plaster, Cement,...                                           0.477156
# Exports of 'Base Metals And Articles Of Base Me...                                           0.532411
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.087664
# Exports of 'Live Animals; Animal Products'                                                   0.344543
# Exports of 'Machinery And Mechanical Appliances...                                           0.544932
# Exports of 'Mineral Products'                                                                0.465394
# Exports of 'Miscellaneous Manufactured Articles'                                             0.485415
# Exports of 'Natural Or Cultured Pearls, Preciou...                                           0.428396
# Exports of 'Optical, Photographic, Cinematograp...                                           0.373085
# Exports of 'Plastics And Articles Thereof; Rubb...                                           0.599085
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.582165
# Exports of 'Products Of The Chemical Or Allied ...                                           0.449633
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.419349
# Exports of 'Raw Hides And Skins, Leather, Fursk...                                           0.343726
# Exports of 'Textiles And Textile Articles'                                                   0.368954
# Exports of 'Vegetable Products'                                                              0.565864
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.435264
# Exports of 'Wood And Articles Of Wood; Wood Cha...                                           0.516376
# Exports of 'Works Of Art, Collectors' Pieces An...                                                NaN
# Imports of 'Animal Or Vegetable Fats And Oils A...                                           0.537970
# Imports of 'Arms And Ammunition; Parts And Acce...                                           0.398171
# Imports of 'Articles Of Stone, Plaster, Cement,...                                           0.608676
# Imports of 'Base Metals And Articles Of Base Me...                                           0.597272
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.442310
# Imports of 'Live Animals; Animal Products'                                                   0.425479
# Imports of 'Machinery And Mechanical Appliances...                                           0.511879
# Imports of 'Mineral Products'                                                                0.618531
# Imports of 'Miscellaneous Manufactured Articles'                                             0.635202
# ...                                                                                               ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.453442
# Imports of 'Products Of The Chemical Or Allied ...                                           0.611812
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.639409
# Imports of 'Raw Hides And Skins, Leather, Fursk...                                           0.479883
# Imports of 'Textiles And Textile Articles'                                                   0.644269
# Imports of 'Vegetable Products'                                                              0.425020
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.598796
# Imports of 'Wood And Articles Of Wood; Wood Cha...                                           0.450427
# Imports of 'Works Of Art, Collectors' Pieces An...                                           0.353690
# Wages of 'CIIU seccion 1'                                                                    0.451379
# Wages of 'CIIU seccion 10'                                                                   0.416723
# Wages of 'CIIU seccion 11'                                                                   0.549711
# Wages of 'CIIU seccion 12'                                                                   0.501925
# Wages of 'CIIU seccion 13'                                                                   0.545188
# Wages of 'CIIU seccion 14'                                                                   0.629791
# Wages of 'CIIU seccion 15'                                                                   0.841559
# Wages of 'CIIU seccion 16'                                                                        NaN
# Wages of 'CIIU seccion 17'                                                                   0.682983
# Wages of 'CIIU seccion 18'                                                                   0.429916
# Wages of 'CIIU seccion 19'                                                                   0.746279
# Wages of 'CIIU seccion 2'                                                                    0.161946
# Wages of 'CIIU seccion 20'                                                                   0.299954
# Wages of 'CIIU seccion 21'                                                                        NaN
# Wages of 'CIIU seccion 3'                                                                    0.592514
# Wages of 'CIIU seccion 4'                                                                    0.515218
# Wages of 'CIIU seccion 5'                                                                    0.562939
# Wages of 'CIIU seccion 6'                                                                    0.438819
# Wages of 'CIIU seccion 7'                                                                    0.577688
# Wages of 'CIIU seccion 8'                                                                    0.508197
# Wages of 'CIIU seccion 9'                                                                    0.610108
#
#                                                     Exports of 'Articles Of Stone, Plaster, Cement, Asbestos, Mica Or Similar Materials; Ceramic Products; Glass And Glassware'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                                           0.360671
# Exports of 'Arms And Ammunition; Parts And Acce...                                           0.477156
# Exports of 'Articles Of Stone, Plaster, Cement,...                                           1.000000
# Exports of 'Base Metals And Articles Of Base Me...                                           0.270373
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.543714
# Exports of 'Live Animals; Animal Products'                                                   0.170166
# Exports of 'Machinery And Mechanical Appliances...                                           0.541754
# Exports of 'Mineral Products'                                                                0.168631
# Exports of 'Miscellaneous Manufactured Articles'                                             0.581304
# Exports of 'Natural Or Cultured Pearls, Preciou...                                           0.167939
# Exports of 'Optical, Photographic, Cinematograp...                                           0.422281
# Exports of 'Plastics And Articles Thereof; Rubb...                                           0.539770
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.188826
# Exports of 'Products Of The Chemical Or Allied ...                                           0.466375
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.384147
# Exports of 'Raw Hides And Skins, Leather, Fursk...                                           0.185469
# Exports of 'Textiles And Textile Articles'                                                   0.523877
# Exports of 'Vegetable Products'                                                              0.281675
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.290185
# Exports of 'Wood And Articles Of Wood; Wood Cha...                                           0.124907
# Exports of 'Works Of Art, Collectors' Pieces An...                                           0.327998
# Imports of 'Animal Or Vegetable Fats And Oils A...                                           0.274579
# Imports of 'Arms And Ammunition; Parts And Acce...                                           0.270549
# Imports of 'Articles Of Stone, Plaster, Cement,...                                           0.544827
# Imports of 'Base Metals And Articles Of Base Me...                                           0.421805
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.357287
# Imports of 'Live Animals; Animal Products'                                                   0.530494
# Imports of 'Machinery And Mechanical Appliances...                                           0.447251
# Imports of 'Mineral Products'                                                                0.460403
# Imports of 'Miscellaneous Manufactured Articles'                                             0.502003
# ...                                                                                               ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.286093
# Imports of 'Products Of The Chemical Or Allied ...                                           0.485061
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.442304
# Imports of 'Raw Hides And Skins, Leather, Fursk...                                           0.323153
# Imports of 'Textiles And Textile Articles'                                                   0.484691
# Imports of 'Vegetable Products'                                                              0.398618
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.351936
# Imports of 'Wood And Articles Of Wood; Wood Cha...                                           0.448169
# Imports of 'Works Of Art, Collectors' Pieces An...                                           0.238986
# Wages of 'CIIU seccion 1'                                                                    0.110337
# Wages of 'CIIU seccion 10'                                                                   0.390062
# Wages of 'CIIU seccion 11'                                                                   0.214141
# Wages of 'CIIU seccion 12'                                                                   0.216208
# Wages of 'CIIU seccion 13'                                                                   0.322051
# Wages of 'CIIU seccion 14'                                                                   0.227082
# Wages of 'CIIU seccion 15'                                                                   0.016033
# Wages of 'CIIU seccion 16'                                                                   0.125431
# Wages of 'CIIU seccion 17'                                                                   0.110709
# Wages of 'CIIU seccion 18'                                                                  -0.122627
# Wages of 'CIIU seccion 19'                                                                   0.216917
# Wages of 'CIIU seccion 2'                                                                    0.208649
# Wages of 'CIIU seccion 20'                                                                   0.277389
# Wages of 'CIIU seccion 21'                                                                   0.256025
# Wages of 'CIIU seccion 3'                                                                    0.428806
# Wages of 'CIIU seccion 4'                                                                    0.204093
# Wages of 'CIIU seccion 5'                                                                    0.200799
# Wages of 'CIIU seccion 6'                                                                    0.344759
# Wages of 'CIIU seccion 7'                                                                    0.400054
# Wages of 'CIIU seccion 8'                                                                    0.293509
# Wages of 'CIIU seccion 9'                                                                    0.325074
#
#                                                     Exports of 'Base Metals And Articles Of Base Metal'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                                           0.550118
# Exports of 'Arms And Ammunition; Parts And Acce...                                           0.532411
# Exports of 'Articles Of Stone, Plaster, Cement,...                                           0.270373
# Exports of 'Base Metals And Articles Of Base Me...                                           1.000000
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.394557
# Exports of 'Live Animals; Animal Products'                                                   0.489346
# Exports of 'Machinery And Mechanical Appliances...                                           0.634768
# Exports of 'Mineral Products'                                                                0.567483
# Exports of 'Miscellaneous Manufactured Articles'                                             0.395002
# Exports of 'Natural Or Cultured Pearls, Preciou...                                           0.398770
# Exports of 'Optical, Photographic, Cinematograp...                                           0.628347
# Exports of 'Plastics And Articles Thereof; Rubb...                                           0.683954
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.236727
# Exports of 'Products Of The Chemical Or Allied ...                                           0.708487
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.506944
# Exports of 'Raw Hides And Skins, Leather, Fursk...                                           0.303073
# Exports of 'Textiles And Textile Articles'                                                   0.468319
# Exports of 'Vegetable Products'                                                              0.302756
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.657320
# Exports of 'Wood And Articles Of Wood; Wood Cha...                                           0.138818
# Exports of 'Works Of Art, Collectors' Pieces An...                                           0.199861
# Imports of 'Animal Or Vegetable Fats And Oils A...                                           0.432266
# Imports of 'Arms And Ammunition; Parts And Acce...                                           0.338520
# Imports of 'Articles Of Stone, Plaster, Cement,...                                           0.709832
# Imports of 'Base Metals And Articles Of Base Me...                                           0.657957
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.667982
# Imports of 'Live Animals; Animal Products'                                                   0.587948
# Imports of 'Machinery And Mechanical Appliances...                                           0.685421
# Imports of 'Mineral Products'                                                                0.565991
# Imports of 'Miscellaneous Manufactured Articles'                                             0.671989
# ...                                                                                               ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.542784
# Imports of 'Products Of The Chemical Or Allied ...                                           0.674355
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.509710
# Imports of 'Raw Hides And Skins, Leather, Fursk...                                           0.632086
# Imports of 'Textiles And Textile Articles'                                                   0.631075
# Imports of 'Vegetable Products'                                                              0.354708
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.568477
# Imports of 'Wood And Articles Of Wood; Wood Cha...                                           0.414752
# Imports of 'Works Of Art, Collectors' Pieces An...                                           0.557157
# Wages of 'CIIU seccion 1'                                                                    0.219326
# Wages of 'CIIU seccion 10'                                                                   0.639140
# Wages of 'CIIU seccion 11'                                                                   0.580711
# Wages of 'CIIU seccion 12'                                                                   0.527388
# Wages of 'CIIU seccion 13'                                                                   0.605189
# Wages of 'CIIU seccion 14'                                                                   0.569507
# Wages of 'CIIU seccion 15'                                                                   0.248243
# Wages of 'CIIU seccion 16'                                                                   0.104710
# Wages of 'CIIU seccion 17'                                                                   0.460559
# Wages of 'CIIU seccion 18'                                                                   0.309942
# Wages of 'CIIU seccion 19'                                                                   0.503110
# Wages of 'CIIU seccion 2'                                                                    0.471351
# Wages of 'CIIU seccion 20'                                                                   0.388158
# Wages of 'CIIU seccion 21'                                                                   0.194279
# Wages of 'CIIU seccion 3'                                                                    0.560034
# Wages of 'CIIU seccion 4'                                                                    0.553496
# Wages of 'CIIU seccion 5'                                                                    0.520243
# Wages of 'CIIU seccion 6'                                                                    0.690180
# Wages of 'CIIU seccion 7'                                                                    0.639515
# Wages of 'CIIU seccion 8'                                                                    0.651703
# Wages of 'CIIU seccion 9'                                                                    0.563491
#
#                                                     Exports of 'Footwear, Headgear, Umbrellas, Sun Umbrellas, Walking Sticks, Seat-Sticks, Whips, Riding-Crops And Parts Thereof; Prepared Feathers And Articles Made Therewith; Artificial Flowers; Articles Of Human Hair'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                                           0.454870
# Exports of 'Arms And Ammunition; Parts And Acce...                                           0.087664
# Exports of 'Articles Of Stone, Plaster, Cement,...                                           0.543714
# Exports of 'Base Metals And Articles Of Base Me...                                           0.394557
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                                           1.000000
# Exports of 'Live Animals; Animal Products'                                                  -0.016323
# Exports of 'Machinery And Mechanical Appliances...                                           0.438861
# Exports of 'Mineral Products'                                                                0.295510
# Exports of 'Miscellaneous Manufactured Articles'                                             0.419076
# Exports of 'Natural Or Cultured Pearls, Preciou...                                           0.282724
# Exports of 'Optical, Photographic, Cinematograp...                                           0.565595
# Exports of 'Plastics And Articles Thereof; Rubb...                                           0.474394
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.354896
# Exports of 'Products Of The Chemical Or Allied ...                                           0.575087
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.546703
# Exports of 'Raw Hides And Skins, Leather, Fursk...                                           0.416975
# Exports of 'Textiles And Textile Articles'                                                   0.567469
# Exports of 'Vegetable Products'                                                              0.273522
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.252300
# Exports of 'Wood And Articles Of Wood; Wood Cha...                                           0.109870
# Exports of 'Works Of Art, Collectors' Pieces An...                                           0.632413
# Imports of 'Animal Or Vegetable Fats And Oils A...                                           0.025102
# Imports of 'Arms And Ammunition; Parts And Acce...                                           0.147737
# Imports of 'Articles Of Stone, Plaster, Cement,...                                           0.610865
# Imports of 'Base Metals And Articles Of Base Me...                                           0.515895
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                                           0.717740
# Imports of 'Live Animals; Animal Products'                                                   0.401792
# Imports of 'Machinery And Mechanical Appliances...                                           0.533562
# Imports of 'Mineral Products'                                                                0.305430
# Imports of 'Miscellaneous Manufactured Articles'                                             0.588184
# ...                                                                                               ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                                           0.363100
# Imports of 'Products Of The Chemical Or Allied ...                                           0.415378
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                                           0.572990
# Imports of 'Raw Hides And Skins, Leather, Fursk...                                           0.686929
# Imports of 'Textiles And Textile Articles'                                                   0.655497
# Imports of 'Vegetable Products'                                                              0.308118
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                                           0.446122
# Imports of 'Wood And Articles Of Wood; Wood Cha...                                           0.447280
# Imports of 'Works Of Art, Collectors' Pieces An...                                           0.417975
# Wages of 'CIIU seccion 1'                                                                    0.244233
# Wages of 'CIIU seccion 10'                                                                   0.623859
# ...
# Wages of 'CIIU seccion 19'                                           0.671225
# Wages of 'CIIU seccion 2'                                            0.464242
# Wages of 'CIIU seccion 20'                                           0.355380
# Wages of 'CIIU seccion 21'                                           0.593816
# Wages of 'CIIU seccion 3'                                            0.856747
# Wages of 'CIIU seccion 4'                                            0.620335
# Wages of 'CIIU seccion 5'                                            0.581553
# Wages of 'CIIU seccion 6'                                            1.000000
# Wages of 'CIIU seccion 7'                                            0.885043
# Wages of 'CIIU seccion 8'                                            0.824649
# Wages of 'CIIU seccion 9'                                            0.831208
#
#                                                     Wages of 'CIIU seccion 7'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                   0.393349
# Exports of 'Arms And Ammunition; Parts And Acce...                   0.577688
# Exports of 'Articles Of Stone, Plaster, Cement,...                   0.400054
# Exports of 'Base Metals And Articles Of Base Me...                   0.639515
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                   0.534819
# Exports of 'Live Animals; Animal Products'                           0.448899
# Exports of 'Machinery And Mechanical Appliances...                   0.750161
# Exports of 'Mineral Products'                                        0.376066
# Exports of 'Miscellaneous Manufactured Articles'                     0.499745
# Exports of 'Natural Or Cultured Pearls, Preciou...                   0.260573
# Exports of 'Optical, Photographic, Cinematograp...                   0.735978
# Exports of 'Plastics And Articles Thereof; Rubb...                   0.722764
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                   0.382292
# Exports of 'Products Of The Chemical Or Allied ...                   0.687647
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                   0.593103
# Exports of 'Raw Hides And Skins, Leather, Fursk...                   0.353166
# Exports of 'Textiles And Textile Articles'                           0.382371
# Exports of 'Vegetable Products'                                      0.478412
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                   0.682962
# Exports of 'Wood And Articles Of Wood; Wood Cha...                   0.227485
# Exports of 'Works Of Art, Collectors' Pieces An...                   0.430659
# Imports of 'Animal Or Vegetable Fats And Oils A...                   0.619343
# Imports of 'Arms And Ammunition; Parts And Acce...                   0.452692
# Imports of 'Articles Of Stone, Plaster, Cement,...                   0.778020
# Imports of 'Base Metals And Articles Of Base Me...                   0.794822
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                   0.812121
# Imports of 'Live Animals; Animal Products'                           0.754614
# Imports of 'Machinery And Mechanical Appliances...                   0.824902
# Imports of 'Mineral Products'                                        0.672503
# Imports of 'Miscellaneous Manufactured Articles'                     0.829200
# ...                                                                       ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                   0.676227
# Imports of 'Products Of The Chemical Or Allied ...                   0.726894
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                   0.721664
# Imports of 'Raw Hides And Skins, Leather, Fursk...                   0.814952
# Imports of 'Textiles And Textile Articles'                           0.778749
# Imports of 'Vegetable Products'                                      0.594546
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                   0.819936
# Imports of 'Wood And Articles Of Wood; Wood Cha...                   0.673447
# Imports of 'Works Of Art, Collectors' Pieces An...                   0.626684
# Wages of 'CIIU seccion 1'                                            0.659679
# Wages of 'CIIU seccion 10'                                           0.821690
# Wages of 'CIIU seccion 11'                                           0.772716
# Wages of 'CIIU seccion 12'                                           0.807387
# Wages of 'CIIU seccion 13'                                           0.841089
# Wages of 'CIIU seccion 14'                                           0.786288
# Wages of 'CIIU seccion 15'                                           0.387009
# Wages of 'CIIU seccion 16'                                           0.128475
# Wages of 'CIIU seccion 17'                                           0.535504
# Wages of 'CIIU seccion 18'                                           0.573067
# Wages of 'CIIU seccion 19'                                           0.715766
# Wages of 'CIIU seccion 2'                                            0.423481
# Wages of 'CIIU seccion 20'                                           0.428680
# Wages of 'CIIU seccion 21'                                           0.637495
# Wages of 'CIIU seccion 3'                                            0.889483
# Wages of 'CIIU seccion 4'                                            0.638346
# Wages of 'CIIU seccion 5'                                            0.620477
# Wages of 'CIIU seccion 6'                                            0.885043
# Wages of 'CIIU seccion 7'                                            1.000000
# Wages of 'CIIU seccion 8'                                            0.886779
# Wages of 'CIIU seccion 9'                                            0.843752
#
#                                                     Wages of 'CIIU seccion 8'  \
# Exports of 'Animal Or Vegetable Fats And Oils A...                   0.376562
# Exports of 'Arms And Ammunition; Parts And Acce...                   0.508197
# Exports of 'Articles Of Stone, Plaster, Cement,...                   0.293509
# Exports of 'Base Metals And Articles Of Base Me...                   0.651703
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                   0.377439
# Exports of 'Live Animals; Animal Products'                           0.491675
# Exports of 'Machinery And Mechanical Appliances...                   0.737261
# Exports of 'Mineral Products'                                        0.338520
# Exports of 'Miscellaneous Manufactured Articles'                     0.443512
# Exports of 'Natural Or Cultured Pearls, Preciou...                   0.289860
# Exports of 'Optical, Photographic, Cinematograp...                   0.693317
# Exports of 'Plastics And Articles Thereof; Rubb...                   0.696765
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                   0.377899
# Exports of 'Products Of The Chemical Or Allied ...                   0.593297
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                   0.525216
# Exports of 'Raw Hides And Skins, Leather, Fursk...                   0.239331
# Exports of 'Textiles And Textile Articles'                           0.413299
# Exports of 'Vegetable Products'                                      0.449143
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                   0.682787
# Exports of 'Wood And Articles Of Wood; Wood Cha...                   0.244568
# Exports of 'Works Of Art, Collectors' Pieces An...                   0.187715
# Imports of 'Animal Or Vegetable Fats And Oils A...                   0.588449
# Imports of 'Arms And Ammunition; Parts And Acce...                   0.462159
# Imports of 'Articles Of Stone, Plaster, Cement,...                   0.724855
# Imports of 'Base Metals And Articles Of Base Me...                   0.764954
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                   0.689714
# Imports of 'Live Animals; Animal Products'                           0.725535
# Imports of 'Machinery And Mechanical Appliances...                   0.785494
# Imports of 'Mineral Products'                                        0.631188
# Imports of 'Miscellaneous Manufactured Articles'                     0.757341
# ...                                                                       ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                   0.642993
# Imports of 'Products Of The Chemical Or Allied ...                   0.698245
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                   0.687197
# Imports of 'Raw Hides And Skins, Leather, Fursk...                   0.676233
# Imports of 'Textiles And Textile Articles'                           0.678750
# Imports of 'Vegetable Products'                                      0.528523
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                   0.772280
# Imports of 'Wood And Articles Of Wood; Wood Cha...                   0.623550
# Imports of 'Works Of Art, Collectors' Pieces An...                   0.564761
# Wages of 'CIIU seccion 1'                                            0.653343
# Wages of 'CIIU seccion 10'                                           0.761788
# Wages of 'CIIU seccion 11'                                           0.674552
# Wages of 'CIIU seccion 12'                                           0.748818
# Wages of 'CIIU seccion 13'                                           0.786912
# Wages of 'CIIU seccion 14'                                           0.792548
# Wages of 'CIIU seccion 15'                                           0.371162
# Wages of 'CIIU seccion 16'                                          -0.054657
# Wages of 'CIIU seccion 17'                                           0.516349
# Wages of 'CIIU seccion 18'                                           0.521747
# Wages of 'CIIU seccion 19'                                           0.681242
# Wages of 'CIIU seccion 2'                                            0.363560
# Wages of 'CIIU seccion 20'                                           0.293798
# Wages of 'CIIU seccion 21'                                           0.392482
# Wages of 'CIIU seccion 3'                                            0.859299
# Wages of 'CIIU seccion 4'                                            0.601357
# Wages of 'CIIU seccion 5'                                            0.593156
# Wages of 'CIIU seccion 6'                                            0.824649
# Wages of 'CIIU seccion 7'                                            0.886779
# Wages of 'CIIU seccion 8'                                            1.000000
# Wages of 'CIIU seccion 9'                                            0.770440
#
#                                                     Wages of 'CIIU seccion 9'
# Exports of 'Animal Or Vegetable Fats And Oils A...                   0.321524
# Exports of 'Arms And Ammunition; Parts And Acce...                   0.610108
# Exports of 'Articles Of Stone, Plaster, Cement,...                   0.325074
# Exports of 'Base Metals And Articles Of Base Me...                   0.563491
# Exports of 'Footwear, Headgear, Umbrellas, Sun ...                   0.459907
# Exports of 'Live Animals; Animal Products'                           0.394802
# Exports of 'Machinery And Mechanical Appliances...                   0.705702
# Exports of 'Mineral Products'                                        0.343260
# Exports of 'Miscellaneous Manufactured Articles'                     0.370980
# Exports of 'Natural Or Cultured Pearls, Preciou...                   0.176215
# Exports of 'Optical, Photographic, Cinematograp...                   0.643253
# Exports of 'Plastics And Articles Thereof; Rubb...                   0.599566
# Exports of 'Prepared Foodstuffs; Beverages, Spi...                   0.392377
# Exports of 'Products Of The Chemical Or Allied ...                   0.543447
# Exports of 'Pulp Of Wood Or Of Other Fibrous Ce...                   0.486685
# Exports of 'Raw Hides And Skins, Leather, Fursk...                   0.191297
# Exports of 'Textiles And Textile Articles'                           0.373667
# Exports of 'Vegetable Products'                                      0.375385
# Exports of 'Vehicles, Aircraft, Vessels And Ass...                   0.656117
# Exports of 'Wood And Articles Of Wood; Wood Cha...                   0.264378
# Exports of 'Works Of Art, Collectors' Pieces An...                   0.138519
# Imports of 'Animal Or Vegetable Fats And Oils A...                   0.510216
# Imports of 'Arms And Ammunition; Parts And Acce...                   0.350680
# Imports of 'Articles Of Stone, Plaster, Cement,...                   0.735589
# Imports of 'Base Metals And Articles Of Base Me...                   0.747730
# Imports of 'Footwear, Headgear, Umbrellas, Sun ...                   0.724151
# Imports of 'Live Animals; Animal Products'                           0.624121
# Imports of 'Machinery And Mechanical Appliances...                   0.750909
# Imports of 'Mineral Products'                                        0.588363
# Imports of 'Miscellaneous Manufactured Articles'                     0.762592
# ...                                                                       ...
# Imports of 'Prepared Foodstuffs; Beverages, Spi...                   0.584424
# Imports of 'Products Of The Chemical Or Allied ...                   0.645328
# Imports of 'Pulp Of Wood Or Of Other Fibrous Ce...                   0.629690
# Imports of 'Raw Hides And Skins, Leather, Fursk...                   0.736633
# Imports of 'Textiles And Textile Articles'                           0.749342
# Imports of 'Vegetable Products'                                      0.476566
# Imports of 'Vehicles, Aircraft, Vessels And Ass...                   0.708600
# Imports of 'Wood And Articles Of Wood; Wood Cha...                   0.599867
# Imports of 'Works Of Art, Collectors' Pieces An...                   0.578135
# Wages of 'CIIU seccion 1'                                            0.451084
# Wages of 'CIIU seccion 10'                                           0.707931
# Wages of 'CIIU seccion 11'                                           0.727603
# Wages of 'CIIU seccion 12'                                           0.748462
# Wages of 'CIIU seccion 13'                                           0.750398
# Wages of 'CIIU seccion 14'                                           0.727829
# Wages of 'CIIU seccion 15'                                           0.281829
# Wages of 'CIIU seccion 16'                                           0.112293
# Wages of 'CIIU seccion 17'                                           0.471830
# Wages of 'CIIU seccion 18'                                           0.497410
# Wages of 'CIIU seccion 19'                                           0.678585
# Wages of 'CIIU seccion 2'                                            0.405940
# Wages of 'CIIU seccion 20'                                           0.365533
# Wages of 'CIIU seccion 21'                                           0.599518
# Wages of 'CIIU seccion 3'                                            0.800100
# Wages of 'CIIU seccion 4'                                            0.565180
# Wages of 'CIIU seccion 5'                                            0.530225
# Wages of 'CIIU seccion 6'                                            0.831208
# Wages of 'CIIU seccion 7'                                            0.843752
# Wages of 'CIIU seccion 8'                                            0.770440
# Wages of 'CIIU seccion 9'                                            1.000000
#
# [63 rows x 63 columns]

# %% [markdown]
# ### Trying to add some info to the nodes...

# %%
k = .05
max_d = 10

for conf in confs:
    (CIIU_lev, HS_Exp, HS_Imp) = conf
    col_name = ctry_str+'_'+geo_str+'_'+'_'.join([c for c in conf])+var_str
    print col_name
    
    for i in range(10):


        nodes = pd.read_csv('data/node_refs/'+col_name+'_nodes_meta.csv', index_col = 0)
        print len(nodes)
        edges = pd.read_csv('data/node_refs/'+col_name+'_edges.csv', index_col = 0)

        ### Max degree = max_d
        df1 = edges.groupby('label_x').apply(lambda x: x.nlargest(max_d, 'weight_COM')).reset_index(drop = True)
        df2 = edges.groupby('label_y').apply(lambda x: x.nlargest(max_d, 'weight_COM')).reset_index(drop = True)
        edges = df1.merge(df2, on = ['label_x', 'label_y', 'weight_COM']).reset_index(drop = True)

        G = nx.from_pandas_dataframe(edges, 'label_x', 'label_y', 'weight_'+geo_str)


        ### Subgraph - neighborhood
    #         nodes_sel = select_nodes_by_kw(G, ['Wine','grape', 'Grape','bebidas fermentadas'])
    #     nodes_sel = [ 'Output ofPesca maritima ']
    #     nodes_sel = select_nodes_by_kw(G, ['Silvicultura'])
        nodes_sel = choice(G.nodes(), 1)

        G = G.subgraph(second_neighbors(G, nodes_sel, second_order=True))  
        nodes = nodes.set_index('node_name').loc[G.nodes()].reset_index()
        edges = edges.loc[(edges.label_x.isin(G.nodes())) & (edges.label_y.isin(G.nodes()))]

        # nx.write_gexf(G,'networks/'+col_name+'.gexf')

    #     Networkx drawing
        #Perform Graph Drawing
        plt.figure(figsize=(8, 8))
        pos = nx.spring_layout(G, k=0.15)

        nx.draw(G, pos, node_size = 10 * nodes.node_size.values, alpha=.6, node_color= list(nodes.color.values), edgelist = [])
        nx.draw_networkx_edges(G, pos, edge_color='.7', alpha=.3)
        #     plt.savefig('../DataViva/Figures/'+'_'+kw+'_'+name)
        plt.show()

        ####

    #     Bokeh drawing
        ####

        N = len(nodes)
        node_indices = list(range(N))
        # sizes = np.linspace(10, 20, N)
        # node_sizes = np.sqrt(nodes['node_size'].values)

        plot = figure(title="Networkx Integration Demonstration", x_range=(-1.1,1.1), y_range=(-1.1,1.1))

        #####

        graph = from_networkx(G, nx.spring_layout, center=(0,0), k = k)

        graph.node_renderer.data_source.add(list(nodes['color'].values), 'color')
        graph.node_renderer.data_source.add(list(nodes['node_name'].values), 'node_name')
        graph.node_renderer.data_source.add(list(2*nodes['node_size'].values), 'node_size')

        graph.node_renderer.glyph = Circle(size='node_size', fill_color='color')
        graph.node_renderer.selection_glyph = Circle(size=15, fill_color='#808000')
        graph.node_renderer.hover_glyph = Circle(size=15, fill_color='#808000')

        graph.edge_renderer.glyph = MultiLine(line_color="#CCCCCC", line_alpha=0.2, line_width=1)
        graph.edge_renderer.selection_glyph = MultiLine(line_color='#808000', line_width=5)
        graph.edge_renderer.hover_glyph = MultiLine(line_color='#808000', line_width=5)
        graph.selection_policy = NodesAndLinkedEdges()

        plot.renderers.append(graph)

        hover = HoverTool(plot=plot, tooltips=dict(act="@node_name", value="@node_size"))
        # hover = HoverTool(tooltips = [('Info', '@node_name'),('(x,y)', '($x, $y)')])

        plot.add_tools(hover)

#         output_file("networkx_graph.html")
        # output_notebook()
        show(plot)

        nodes = nodes.sort_values(by = 'node_size', ascending = False)
        sns.barplot(x='node_size',y='node_name',palette=nodes['color'], data=nodes, edgecolor = 'None')

# %%
conf
